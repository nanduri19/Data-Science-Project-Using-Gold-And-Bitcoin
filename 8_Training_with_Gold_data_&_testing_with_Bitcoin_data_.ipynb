# %% [markdown]
# <a href="https://colab.research.google.com/github/nanduri19/Data-Science-Project-Using-Gold-And-Bitcoin/blob/main/8_Training_with_Gold_data_%26_testing_with_Bitcoin_data_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd_Price_Of_Historicaldata
import numpy as mu_Price_Of_Historicaldata
import warnings as rw_Price_Of_Historicaldata
rw_Price_Of_Historicaldata.filterwarnings("ignore")

# %%
from google.colab import drivey drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
GOld_Price_Of_Historicaldata = pd_Price_Of_Historicaldata.read_csv("/content/drive/MyDrive/Gold_final_data.csv")
GOld_Price_Of_Historicaldata.replace([mu_Price_Of_Historicaldata.inf, -mu_Price_Of_Historicaldata.inf], mu_Price_Of_Historicaldata.nan, inplace=True)
GOld_Price_Of_Historicaldata.fillna(999, inplace=True)
print("Shape details: ",GOld_Price_Of_Historicaldata.shape)
print("Columns details: ",GOld_Price_Of_Historicaldata.columns)
GOld_Price_Of_Historicaldata
# Out:
# Shape details:  (4999, 2)
# Columns details:  Index(['Date', 'Price'], dtype='object')
#             Date  Price
# 0     03/11/2023  999.0
# 1     02/11/2023  999.0
# 2     01/11/2023  999.0
# 3     31/10/2023  999.0
# 4     30/10/2023  999.0
# ...          ...    ...
# 4994  09/01/2004  426.8
# 4995  08/01/2004  424.4
# 4996  07/01/2004  422.3
# 4997  06/01/2004  423.2
# 4998  05/01/2004  424.8
#
# [4999 rows x 2 columns]

# %%
Coin_Price_Of_Historicaldata = pd_Price_Of_Historicaldata.read_csv("/content/drive/MyDrive/Bitcoin_final_data.csv")
Coin_Price_Of_Historicaldata.replace([mu_Price_Of_Historicaldata.inf, -mu_Price_Of_Historicaldata.inf], mu_Price_Of_Historicaldata.nan, inplace=True)
Coin_Price_Of_Historicaldata.fillna(999, inplace=True)
print("Shape details: ",Coin_Price_Of_Historicaldata.shape)
print("Columns details: ",Coin_Price_Of_Historicaldata.columns)
Coin_Price_Of_Historicaldata
# Out:
# Shape details:  (1882, 2)
# Columns details:  Index(['Date', 'BTC_Closing'], dtype='object')
#             Date   BTC_Closing
# 0     2018-02-01   9170.540039
# 1     2018-02-02   8830.750000
# 2     2018-02-03   9174.910156
# 3     2018-02-04   8277.009766
# 4     2018-02-05   6955.270020
# ...          ...           ...
# 1877  2023-03-27  27139.888672
# 1878  2023-03-28  27268.130859
# 1879  2023-03-29  28348.441406
# 1880  2023-03-30  28033.562500
# 1881  2023-03-31  28478.484375
#
# [1882 rows x 2 columns]

# %%
import tensorflow as txttflo
from keras.layers import Dense as txttdnse
from keras.layers import GRU as txttgrunt
from sklearn.metrics import r2_score as txtr2scre
from sklearn.metrics import mean_squared_error as txtrmeaser
from sklearn.metrics import mean_absolute_error as txtrmeasqr
from sklearn.model_selection import train_test_split as txtrtsplt
from sklearn.preprocessing import MinMaxScaler as txtrtmnmxsler
from tensorflow.keras.layers import Bidirectional as price_of_histbidirct

# %%
def His_SEGFn(txtIpXts_se_His, txtIpXts_n_His):
    vax_txtIpXts, vay_txtIpXts = [], []

    for RRr in range(len(txtIpXts_se_His)):
        Ad_txtIp = RRr + txtIpXts_n_His
        if Ad_txtIp > len(txtIpXts_se_His) - 1:
            break
        x_txtIpXts, y_txtIpXts = txtIpXts_se_His[RRr:Ad_txtIp], txtIpXts_se_His[Ad_txtIp]
        vax_txtIpXts.append(x_txtIpXts)
        vay_txtIpXts.append(y_txtIpXts)
    return mu_Price_Of_Historicaldata.array(vax_txtIpXts), mu_Price_Of_Historicaldata.array(vay_txtIpXts)

txtIpXts_n_His = 20

# %%
## train data is - Gold data
vax_txtIpXts_Tnn, vay_txtIpXts_Tnn = His_SEGFn(GOld_Price_Of_Historicaldata['Price'].tolist(), txtIpXts_n_His)
## test data is - Bitcoin data
vax_txtIpXts_Tss, vay_txtIpXts_Tss = His_SEGFn(Coin_Price_Of_Historicaldata['BTC_Closing'].tolist(), txtIpXts_n_His)
for total in range(len(vax_txtIpXts_Tss)):
    print(vax_txtIpXts_Tss[total], vay_txtIpXts_Tss[total])
# Out:
# Streaming output truncated to the last 5000 lines.
#  9386.78808594 9450.70214844 9538.02441406 9480.25488281 9411.84082031
#  9288.01855469 9332.34082031 9303.62988281 9648.71777344 9629.65820312
#  9313.61035156 9264.81347656 9162.91796875 9045.390625   9143.58203125] 9190.8544921875
# [9870.09472656 9321.78125    9480.84375    9475.27734375 9386.78808594
#  9450.70214844 9538.02441406 9480.25488281 9411.84082031 9288.01855469
#  9332.34082031 9303.62988281 9648.71777344 9629.65820312 9313.61035156
#  9264.81347656 9162.91796875 9045.390625   9143.58203125 9190.85449219] 9137.9931640625
# [9321.78125    9480.84375    9475.27734375 9386.78808594 9450.70214844
#  9538.02441406 9480.25488281 9411.84082031 9288.01855469 9332.34082031
#  9303.62988281 9648.71777344 9629.65820312 9313.61035156 9264.81347656
#  9162.91796875 9045.390625   9143.58203125 9190.85449219 9137.99316406] 9228.3251953125
# [9480.84375    9475.27734375 9386.78808594 9450.70214844 9538.02441406
# ...

# %%
srtxtrtmnmxsler = txtrtmnmxsler()
vax_txtIpXts_Tnn_sca = srtxtrtmnmxsler.fit_transform(vax_txtIpXts_Tnn)
vax_txtIpXts_Tss_sca = srtxtrtmnmxsler.transform(vax_txtIpXts_Tss)

txtIpXtrrshped = vax_txtIpXts_Tnn_sca.reshape((vax_txtIpXts_Tnn_sca.shape[0], 1, vax_txtIpXts_Tnn_sca.shape[1]))
txtIpXtsrshped = vax_txtIpXts_Tss_sca.reshape((vax_txtIpXts_Tss_sca.shape[0], 1, vax_txtIpXts_Tss_sca.shape[1]))

# %% [markdown]
#  changing both Optimizer and activation function

# %% [markdown]
# GRU

# %%
txtoptmzers = ['adam', 'sgd', 'rmsprop', 'adadelta', 'adagrad', 'adamax', 'nadam']
txtoactvtns = ['relu', 'tanh', 'sigmoid']

for txtoptmzer in txtoptmzers:
  for txtoactvtn in txtoactvtns:
    txtmdle = txttflo.keras.models.Sequential()
    txtmdle.add(txttgrunt(32, activation=txtoactvtn, input_shape=(txtIpXtrrshped.shape[1], txtIpXtrrshped.shape[2])))
    txtmdle.add(txttdnse(1))
    txtmdle.compile(optimizer=txtoptmzer, loss='mse', metrics=['accuracy'])

    txtmdle.fit(txtIpXtrrshped, vay_txtIpXts_Tnn, epochs=30, batch_size=72, verbose=0)
    txtprdtns = txtmdle.predict(txtIpXtsrshped)
    txtr2sr = txtr2scre(vay_txtIpXts_Tss, txtprdtns)
    txtmsae = txtrmeaser(vay_txtIpXts_Tss, txtprdtns)
    txtmase = txtrmeasqr(vay_txtIpXts_Tss, txtprdtns)

    print(f'Optimizer is: {txtoptmzer}, activation is: {txtoactvtn}')
    print('R-squared:', txtr2sr)
    print('Mean Squared Error:', txtmsae)
    print('Mean Absolute Error:', txtmase)
    print('---')
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# Optimizer is: adam, activation is: relu
# R-squared: 0.49710692422588165
# Mean Squared Error: 141245184.43697855
# Mean Absolute Error: 8702.64978617372
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Optimizer is: adam, activation is: tanh
# R-squared: -1.5170546480173415
# Mean Squared Error: 706953157.8852983
# Mean Absolute Error: 20641.89714766522
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Optimizer is: adam, activation is: sigmoid
# R-squared: -1.5179726471230133
# Mean Squared Error: 707210991.9244606
# Mean Absolute Error: 20648.14160872479
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Optimizer is: sgd, activation is: relu
# R-squared: -1.3991873309799225
# Mean Squared Error: 673848325.5938315
# Mean Absolute Error: 19823.800986776547
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Optimizer is: sgd, activation is: tanh
# R-squared: -1.3378466101408786
# Mean Squared Error: 656619849.3117291
# ...

# %% [markdown]
# BiDirectional GRU

# %%
txtoptmzers = ['adam', 'sgd', 'rmsprop', 'adadelta', 'adagrad', 'adamax', 'nadam']
txtoactvtns = ['relu', 'tanh', 'sigmoid']

for txtoptmzer in txtoptmzers:
  for txtoactvtn in txtoactvtns:
    txtmdle = txttflo.keras.models.Sequential()
    txtmdle.add(price_of_histbidirct(txttgrunt(32, activation=txtoactvtn, input_shape=(txtIpXtrrshped.shape[1], txtIpXtrrshped.shape[2]))))
    txtmdle.add(txttdnse(1))
    txtmdle.compile(optimizer=txtoptmzer, loss='mse')

    txtmdle.fit(txtIpXtrrshped, vay_txtIpXts_Tnn, epochs=30, batch_size=72, verbose=0)
    txtprdtns = txtmdle.predict(txtIpXtsrshped)
    txtr2sr = txtr2scre(vay_txtIpXts_Tss, txtprdtns)
    txtmsae = txtrmeaser(vay_txtIpXts_Tss, txtprdtns)
    txtmase = txtrmeasqr(vay_txtIpXts_Tss, txtprdtns)

    print(f'Optimizer is: {txtoptmzer}, activation is: {txtoactvtn}')
    print('R-squared:', txtr2sr)
    print('Mean Squared Error:', txtmsae)
    print('Mean Absolute Error:', txtmase)
    print('---')
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Optimizer is: adam, activation is: relu
# R-squared: 0.4740994249941257
# Mean Squared Error: 147707191.23120743
# Mean Absolute Error: 8916.056674715528
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Optimizer is: adam, activation is: tanh
# R-squared: -1.5067795294962618
# Mean Squared Error: 704067234.2555333
# Mean Absolute Error: 20571.87386275311
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Optimizer is: adam, activation is: sigmoid
# R-squared: -1.5073163634276114
# Mean Squared Error: 704218012.2465183
# Mean Absolute Error: 20575.538199911312
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Optimizer is: sgd, activation is: relu
# R-squared: -1.3990059304423097
# Mean Squared Error: 673797376.4882932
# Mean Absolute Error: 19822.515909164216
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Optimizer is: sgd, activation is: tanh
# R-squared: -1.3243697244503054
# Mean Squared Error: 652834660.5773824
# ...

# %% [markdown]
# LSTM

# %%
from keras.layers import LSTM as txttlngtm

# %%
txtoptmzers = ['adam', 'sgd', 'rmsprop', 'adadelta', 'adagrad', 'adamax', 'nadam']
txtoactvtns = ['relu', 'tanh', 'sigmoid']

for txtoptmzer in txtoptmzers:
  for txtoactvtn in txtoactvtns:
    txtmdle = txttflo.keras.models.Sequential()
    txtmdle.add(txttlngtm(32, activation=txtoactvtn, input_shape=(txtIpXtrrshped.shape[1], txtIpXtrrshped.shape[2])))
    txtmdle.add(txttdnse(1))
    txtmdle.compile(optimizer=txtoptmzer, loss='mse', metrics=['accuracy'])

    txtmdle.fit(txtIpXtrrshped, vay_txtIpXts_Tnn, epochs=30, batch_size=72, verbose=0)
    txtprdtns = txtmdle.predict(txtIpXtsrshped)
    txtr2sr = txtr2scre(vay_txtIpXts_Tss, txtprdtns)
    txtmsae = txtrmeaser(vay_txtIpXts_Tss, txtprdtns)
    txtmase = txtrmeasqr(vay_txtIpXts_Tss, txtprdtns)

    print(f'Optimizer is: {txtoptmzer}, activation is: {txtoactvtn}')
    print('R-squared:', txtr2sr)
    print('Mean Squared Error:', txtmsae)
    print('Mean Absolute Error:', txtmase)
    print('---')
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Optimizer is: adam, activation is: relu
# R-squared: 0.2799365557947844
# Mean Squared Error: 202240792.09389272
# Mean Absolute Error: 10529.937266348768
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Optimizer is: adam, activation is: tanh
# R-squared: -1.519703594185402
# Mean Squared Error: 707697154.7866185
# Mean Absolute Error: 20659.910811910824
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Optimizer is: adam, activation is: sigmoid
# R-squared: -1.5206924561659827
# Mean Squared Error: 707974891.7441514
# Mean Absolute Error: 20666.631358633236
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Optimizer is: sgd, activation is: relu
# R-squared: -1.399006010107291
# Mean Squared Error: 673797398.8634174
# Mean Absolute Error: 19822.51651990913
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Optimizer is: sgd, activation is: tanh
# R-squared: -1.3930062740819773
# Mean Squared Error: 672112281.5645479
# ...

# %% [markdown]
# Bidirectional LSTM

# %%
txtoptmzers = ['adam', 'sgd', 'rmsprop', 'adadelta', 'adagrad', 'adamax', 'nadam']
txtoactvtns = ['relu', 'tanh', 'sigmoid']

for txtoptmzer in txtoptmzers:
  for txtoactvtn in txtoactvtns:
    txtmdle = txttflo.keras.models.Sequential()
    txtmdle.add(price_of_histbidirct(txttlngtm(32, activation=txtoactvtn, input_shape=(txtIpXtrrshped.shape[1], txtIpXtrrshped.shape[2]))))
    txtmdle.add(txttdnse(1))
    txtmdle.compile(optimizer=txtoptmzer, loss='mse')

    txtmdle.fit(txtIpXtrrshped, vay_txtIpXts_Tnn, epochs=30, batch_size=72, verbose=0)
    txtprdtns = txtmdle.predict(txtIpXtsrshped)
    txtr2sr = txtr2scre(vay_txtIpXts_Tss, txtprdtns)
    txtmsae = txtrmeaser(vay_txtIpXts_Tss, txtprdtns)
    txtmase = txtrmeasqr(vay_txtIpXts_Tss, txtprdtns)

    print(f'Optimizer is: {txtoptmzer}, activation is: {txtoactvtn}')
    print('R-squared:', txtr2sr)
    print('Mean Squared Error:', txtmsae)
    print('Mean Absolute Error:', txtmase)
    print('---')
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Optimizer is: adam, activation is: relu
# R-squared: 0.2970165608871359
# Mean Squared Error: 197443612.3639071
# Mean Absolute Error: 10400.525749362245
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Optimizer is: adam, activation is: tanh
# R-squared: -1.5114671318276267
# Mean Squared Error: 705383818.8094996
# Mean Absolute Error: 20603.84863997479
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Optimizer is: adam, activation is: sigmoid
# R-squared: -1.5127883500176682
# Mean Squared Error: 705754903.0735784
# Mean Absolute Error: 20612.85189009686
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Optimizer is: sgd, activation is: relu
# R-squared: -1.3996333410300879
# Mean Squared Error: 673973594.3136272
# Mean Absolute Error: 19826.96028853436
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Optimizer is: sgd, activation is: tanh
# R-squared: -1.3590334232092451
# Mean Squared Error: 662570488.6496572
# ...

# %% [markdown]
# RNN

# %%
from keras.layers import SimpleRNN as txttsmprn

# %%
txtoptmzers = ['adam', 'sgd', 'rmsprop', 'adadelta', 'adagrad', 'adamax', 'nadam']
txtoactvtns = ['relu', 'tanh', 'sigmoid']

for txtoptmzer in txtoptmzers:
  for txtoactvtn in txtoactvtns:
    txtmdle = txttflo.keras.models.Sequential()
    txtmdle.add(txttsmprn(32, activation=txtoactvtn, input_shape=(txtIpXtrrshped.shape[1], txtIpXtrrshped.shape[2])))
    txtmdle.add(txttdnse(1))
    txtmdle.compile(optimizer=txtoptmzer, loss='mse', metrics=['accuracy'])

    txtmdle.fit(txtIpXtrrshped, vay_txtIpXts_Tnn, epochs=30, batch_size=72, verbose=0)
    txtprdtns = txtmdle.predict(txtIpXtsrshped)
    txtr2sr = txtr2scre(vay_txtIpXts_Tss, txtprdtns)
    txtmsae = txtrmeaser(vay_txtIpXts_Tss, txtprdtns)
    txtmase = txtrmeasqr(vay_txtIpXts_Tss, txtprdtns)

    print(f'Optimizer is: {txtoptmzer}, activation is: {txtoactvtn}')
    print('R-squared:', txtr2sr)
    print('Mean Squared Error:', txtmsae)
    print('Mean Absolute Error:', txtmase)
    print('---')
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Optimizer is: adam, activation is: relu
# R-squared: 0.31915266847082446
# Mean Squared Error: 191226349.19407323
# Mean Absolute Error: 10219.557448046036
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Optimizer is: adam, activation is: tanh
# R-squared: -1.5174927534471556
# Mean Squared Error: 707076206.4720017
# Mean Absolute Error: 20644.87748671551
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Optimizer is: adam, activation is: sigmoid
# R-squared: -1.5187280464937847
# Mean Squared Error: 707423157.3500513
# Mean Absolute Error: 20653.28548211365
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Optimizer is: sgd, activation is: relu
# R-squared: -1.3992373152064772
# Mean Squared Error: 673862364.4256206
# Mean Absolute Error: 19824.155146384725
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Optimizer is: sgd, activation is: tanh
# R-squared: -1.2978460948602568
# Mean Squared Error: 645385094.9860932
# ...

# %% [markdown]
# Bidirectional RNN

# %%
txtoptmzers = ['adam', 'sgd', 'rmsprop', 'adadelta', 'adagrad', 'adamax', 'nadam']
txtoactvtns = ['relu', 'tanh', 'sigmoid']

for txtoptmzer in txtoptmzers:
  for txtoactvtn in txtoactvtns:
    txtmdle = txttflo.keras.models.Sequential()
    txtmdle.add(price_of_histbidirct(txttsmprn(32, activation=txtoactvtn, input_shape=(txtIpXtrrshped.shape[1], txtIpXtrrshped.shape[2]))))
    txtmdle.add(txttdnse(1))
    txtmdle.compile(optimizer=txtoptmzer, loss='mse')

    txtmdle.fit(txtIpXtrrshped, vay_txtIpXts_Tnn, epochs=30, batch_size=72, verbose=0)
    txtprdtns = txtmdle.predict(txtIpXtsrshped)
    txtr2sr = txtr2scre(vay_txtIpXts_Tss, txtprdtns)
    txtmsae = txtrmeaser(vay_txtIpXts_Tss, txtprdtns)
    txtmase = txtrmeasqr(vay_txtIpXts_Tss, txtprdtns)

    print(f'Optimizer is: {txtoptmzer}, activation is: {txtoactvtn}')
    print('R-squared:', txtr2sr)
    print('Mean Squared Error:', txtmsae)
    print('Mean Absolute Error:', txtmase)
    print('---')
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Optimizer is: adam, activation is: relu
# R-squared: 0.28320959665846157
# Mean Squared Error: 201321508.68608636
# Mean Absolute Error: 10506.56968785664
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Optimizer is: adam, activation is: tanh
# R-squared: -1.507499381300255
# Mean Squared Error: 704269415.6052482
# Mean Absolute Error: 20576.787299642758
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Optimizer is: adam, activation is: sigmoid
# R-squared: -1.5074383405721625
# Mean Squared Error: 704252271.386501
# Mean Absolute Error: 20576.370704183773
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Optimizer is: sgd, activation is: relu
# R-squared: -1.3992080349851554
# Mean Squared Error: 673854140.6292309
# Mean Absolute Error: 19823.947654257016
# ---
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Optimizer is: sgd, activation is: tanh
# R-squared: -1.3162961669882574
# Mean Squared Error: 650567078.9229043
# ...
